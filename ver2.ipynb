# %% [markdown]
# # THỰC HÀNH NGÔN NGỮ TỰ NHIÊN

# %%
pip install wordcloud spacy
# Out:
# ...
#
# ...
#      ------------------------------------ 152.1/152.1 kB 824.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 12.2/12.2 MB 484.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 415.3 kB/s eta 0:00:00
# ...
#      -------------------------------------- 48.9/48.9 kB 275.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 587.7 kB/s eta 0:00:00
# ...
#      ------------------------------------ 181.6/181.6 kB 422.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 94.7/94.7 kB 416.1 kB/s eta 0:00:00
# ...
#      ------------------------------------ 480.9/480.9 kB 424.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 2.1 MB/s eta 0:00:00
# ...

# %% [raw]
# Dấu "!" ở đầu câu lệnh cho biết rằng câu lệnh này sẽ được thực thi trong môi trường dòng lệnh của hệ điều hành.

# %%
# !python -m spacy download en
# Out:
# ...
#      ---------------------------------------- 12.8/12.8 MB 5.6 MB/s eta 0:00:00
# ...
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use
# the full pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import wordcloud

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Đoạn mã trên sử dụng thư viện spaCy để phân tích ngôn ngữ tự nhiên (natural language processing) và tách câu thành các từ riêng biệt. Sau đó, vòng lặp for token in doc được sử dụng để in ra từng từ trong câu.
#
# Vì vậy, kết quả bạn nhìn thấy là danh sách các từ trong câu "Apple is looking at buying U.K. startup for $1 billion", mỗi từ trên một dòng.

# %%
doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')

for token in doc:
    print(token)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_)
# Out:
# Apple Apple PROPN NNP
# is be AUX VBZ
# looking look VERB VBG
# at at ADP IN
# buying buy VERB VBG
# U.K. U.K. PROPN NNP
# startup startup NOUN NN
# for for ADP IN
# $ $ SYM $
# 1 1 NUM CD
# billion billion NUM CD

# %% [markdown]
# Đoạn mã trên thực hiện các công việc sau:
# from spacy import displacy: Nhập hàm displacy từ thư viện spaCy để hiển thị biểu đồ phụ thuộc cú pháp.
# displacy.render(doc, style='dep', jupyter=True, options={'distance': 100}): Hiển thị biểu đồ phụ thuộc cú pháp của câu doc với phong cách 'dep'. Các tùy chọn (options) được đặt là {'distance': 100} để xác định khoảng cách giữa các từ trong biểu đồ.
# Khi bạn chạy đoạn mã này trong một môi trường như Jupyter Notebook hoặc Google Colab, nó sẽ tạo ra một biểu đồ phụ thuộc cú pháp và hiển thị nó trực tiếp trong giao diện của môi trường đó. Biểu đồ sẽ cho bạn cái nhìn trực quan về cấu trúc câu và mối quan hệ phụ thuộc giữa các từ.

# %% [markdown]
# Các thông tin được in ra bao gồm:
# token.text: Đây là văn bản (text) của từ đang được xem xét trong vòng lặp.
# token.lemma_: Đây là dạng nguyên mẫu (lemma) của từ. Nó thể hiện dạng căn bản của từ, giúp chuẩn hóa các biến thể của từ đó.
# token.pos_: Đây là phần loại từ (part-of-speech) của từ. Ví dụ: danh từ (NOUN), động từ (VERB), trạng từ (ADV), ...
# token.tag_: Đây là thẻ từ (tag) của từ. Thẻ từ cung cấp thông tin chi tiết hơn về loại từ và các đặc điểm ngữ pháp khác.
# Ví dụ, với từ "Apple", thông tin được in ra là: "Apple Apple PROPN NNP". Điều này có nghĩa là "Apple" là một từ riêng (PROPN) được đánh dấu là danh từ riêng (NNP).
# Tương tự, các thông tin khác cũng được in ra tương ứng cho từng từ trong câu.
# Qua việc in ra thông tin này, bạn có thể nắm bắt được các thuộc tính và đặc điểm của các từ trong câu để phân tích và xử lý văn bản một cách tự động.

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6c388a5b4587407baa46090a58367896-0" class="displacy" width="1150" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
# ...

# %%
text = """But Google is starting from behind. The company made a late push
into hardware, and Apple’s Siri, available on iPhones, and Amazon’s Alexa
software, which runs on its Echo and Dot devices, have clear leads in
consumer adoption."""

doc2 = nlp(text)
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is starting from behind. The company made a late push</br>into hardware, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Siri
# ...

# %%
import requests

metamorphosis_book = requests.get('https://dantri.com.vn/').content
metamorphosis_book[:1000]
# Out:
# b'<!DOCTYPE html>\r\n<html lang="vi" xmlns="http://www.w3.org/1999/xhtml">\r\n<head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no"><meta name="format-detection" content="telephone=no"><meta name="robots" content="index,follow,all"><title>Tin t\xe1\xbb\xa9c Vi\xe1\xbb\x87t Nam v\xc3\xa0 qu\xe1\xbb\x91c t\xe1\xba\xbf n\xc3\xb3ng, nhanh, c\xe1\xba\xadp nh\xe1\xba\xadt 24h | B\xc3\xa1o D\xc3\xa2n tr\xc3\xad</title><meta name="description" content="\xc4\x90\xe1\xbb\x8dc b\xc3\xa1o dantri - Tin t\xe1\xbb\xa9c m\xe1\xbb\x9bi nh\xe1\xba\xa5t, Th\xc3\xb4ng tin nhanh ch\xc3\xadnh x\xc3\xa1c \xc4\x91\xc6\xb0\xe1\xbb\xa3c c\xe1\xba\xadp nh\xe1\xba\xadt h\xc3\xa0ng gi\xe1\xbb\x9d. b\xc3\xa1o n\xc3\xb3i \xc4\x91\xe1\xbb\x8dc tin t\xe1\xbb\xa9c online Vi\xe1\xbb\x87t Nam Th\xe1\xba\xbf gi\xe1\xbb\x9bi n\xc3\xb3ng nh\xe1\xba\xa5t trong ng\xc3\xa0y, Kinh doanh Vi\xe1\xbb\x87c l\xc3\xa0m, Ph\xc3\xa1p lu\xe1
# ...

# %% [markdown]
# Đoạn mã này thực hiện các bước sau:
# Đoạn văn bản được gán cho biến text. Đoạn văn bản này chứa thông tin về Google, Apple, Siri, Amazon, Alexa, và các từ khác liên quan.
# Biến text được đưa vào nlp để tạo đối tượng doc2. Đối tượng này sẽ chứa thông tin phân tích ngôn ngữ tự nhiên (NLP) của đoạn văn bản.
# displacy.render(doc2, style='ent', jupyter=True) sử dụng hàm render từ displacy để hiển thị các thực thể trong đoạn văn bản doc2 với phong cách 'ent' (entities). Khi jupyter=True, biểu đồ sẽ được hiển thị trong giao diện Jupyter Notebook hoặc Google Colab.
# Kết quả sẽ là một biểu đồ hiển thị các thực thể trong đoạn văn bản, ví dụ như các tên riêng (person), tổ chức (organization), và các thực thể khác có ý nghĩa trong ngữ cảnh. Biểu đồ giúp bạn xem xét và khám phá các thực thể quan trọng trong văn bản một cách trực quan.

# %%
# Try to run this cell. Is it giving exception? Why doesn't it work? Think about it for a moment before moving on!
try:
    doc_metamor = nlp(metamorphosis_book)
except TypeError as e:
    print("metamorphosis_book is not converted to string:", str(e))
# Out:
# ---------------------------------------------------------------------------
# ExtraData                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Try to run this cell. Is it giving exception? Why doesn't it work? Think about it for a moment before moving on!
#       2 try:
# ----> 3     doc_metamor = nlp(metamorphosis_book)
#       4 except TypeError as e:
#       5     print("metamorphosis_book is not converted to string:", str(e))
#
# File ~\anaconda3\lib\site-packages\spacy\language.py:999, in Language.__call__(self, text, disable, component_cfg)
#     978 def __call__(
#     979     self,
#     980     text: Union[str, Doc],
#    (...)
#     983     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#     984 ) -> Doc:
#     985     """Apply the pipeline to some text. The text can span multiple sentences,
#     986     and can contain arbitrary whitespace. Alignment into the original string
#     987     is preserved.
#    (...)
# ...

# %% [markdown]
# Đoạn mã gặp lỗi "ExtraData: unpack(b) received extra data." vì việc cung cấp dữ liệu metamorphosis_book cho phương thức nlp() trong spaCy không đúng định dạng.
# Nguyên nhân chính của lỗi này là metamorphosis_book đang chứa nội dung của tệp văn bản dưới dạng bytes, trong khi spaCy yêu cầu dữ liệu đầu vào là một chuỗi (string).
# Để khắc phục lỗi này, bạn cần chuyển đổi dữ liệu metamorphosis_book từ dạng bytes sang dạng chuỗi trước khi truyền nó cho phương thức nlp().
# Để chuyển đổi từ dạng bytes sang chuỗi, bạn có thể sử dụng phương thức decode() trên đối tượng bytes:

# %%
type(metamorphosis_book)
# Out:
# bytes

# %%
"안녕".encode('utf8')
# Out:
# b'\xec\x95\x88\xeb\x85\x95'

# %%
# b'\xec\x95\x88\xeb\x85\x95'.decode('euc-kr') <- what happen if you do this?
b'\xec\x95\x88\xeb\x85\x95'.decode('utf8')
# Out:
# '안녕'

# %%
"안녕".encode('euc-kr')
# Out:
# b'\xbe\xc8\xb3\xe7'

# %%
b'\xbe\xc8\xb3\xe7'.decode('euc-kr')
# Out:
# '안녕'

# %%
b'\xbe\xc8\xb3\xe7'.decode('latin-1')
# Out:
# '¾È³ç'

# %% [markdown]
# Trong  các đoạn mã trên, có sử dụng các phương thức encode() và decode() để chuyển đổi giữa chuỗi và dạng bytes, sử dụng các bộ mã khác nhau.
# "안녕".encode('utf8'):
#
# Phương thức encode() được sử dụng để chuyển đổi chuỗi Unicode "안녕" sang dạng bytes, sử dụng bộ mã UTF-8.
# --> Kết quả trả về là b'\xec\x95\x88\xeb\x85\x95', một dãy bytes biểu diễn chuỗi "안녕" theo bộ mã UTF-8.
#
# b'\xec\x95\x88\xeb\x85\x95'.decode('euc-kr'): Phương thức decode() được sử dụng để chuyển đổi dãy bytes
#
# b'\xec\x95\x88\xeb\x85\x95' thành chuỗi Unicode, sử dụng bộ mã EUC-KR.
#
# Tuy nhiên, việc chuyển đổi không thành công vì dãy bytes này không phù hợp với bộ mã EUC-KR. Do đó, sẽ xảy ra lỗi UnicodeDecodeError nếu bạn cố gắng chuyển đổi theo cách này.
# b'\xec\x95\x88\xeb\x85\x95'.decode('utf8'): Phương thức decode() được sử dụng để chuyển đổi dãy bytes b'\xec\x95\x88\xeb\x85\x95' thành chuỗi Unicode, sử dụng bộ mã UTF-8. Kết quả trả về là chuỗi "안녕", giống với chuỗi ban đầu trước khi chuyển đổi sang dạng bytes.
#
#
# Tóm lại, việc sử dụng encode() và decode() cho phép bạn chuyển đổi giữa chuỗi Unicode và dạng bytes, sử dụng các bộ mã khác nhau. Tuy nhiên, khi thực hiện chuyển đổi, bạn phải đảm bảo sử dụng cùng một bộ mã cho cả hai hàm encode() và decode() để đảm bảo tính nhất quán và thành công trong việc chuyển đổi.

# %%
# TODO: Convert the bytes into string and replace below dummy value with your code.
metamorphosis_book_str = 'DUMMY PLACEHOLDER'

# %%
type(metamorphosis_book_str)
# Out:
# str

# %%
doc_metamor = nlp(metamorphosis_book_str)

# %%
words = [token.text for token in doc_metamor 
         if token.is_stop != True and token.is_punct != True]

# %% [markdown]
# metamorphosis_book_str = 'DUMMY PLACEHOLDER': Đây là một dòng mã được đặt tạm thời để bạn thay thế với mã chuyển đổi từ dạng bytes sang dạng chuỗi. Bạn cần thay thế 'DUMMY PLACEHOLDER' bằng mã chuyển đổi thích hợp.
#
# type(metamorphosis_book_str): Dòng mã này kiểm tra kiểu dữ liệu của metamorphosis_book_str, đảm bảo rằng nó đã được chuyển đổi thành chuỗi (str).
#
# doc_metamor = nlp(metamorphosis_book_str): Đoạn mã này sử dụng đối tượng nlp của spaCy để phân tích ngôn ngữ tự nhiên trên chuỗi metamorphosis_book_str. Đối tượng doc_metamor sẽ chứa kết quả phân tích.
#
# words = [token.text for token in doc_metamor if token.is_stop != True and token.is_punct != True]: Dòng mã này tạo ra một danh sách (list) gồm các từ trong doc_metamor. Các từ được lựa chọn nếu không phải là từ dừng (is_stop != True) và không phải là dấu câu (is_punct != True).
#
# Lưu ý rằng đoạn mã trên cần được hoàn thiện bằng cách chuyển đổi dữ liệu từ dạng bytes sang dạng chuỗi thích hợp. Bạn nên thay thế 'DUMMY PLACEHOLDER' bằng mã chuyển đổi như "metamorphosis_book.decode('utf-8')", với giả định rằng metamorphosis_book là dữ liệu dạng bytes và mã utf-8 là bộ mã được sử dụng để chuyển đổi.

# %%
from collections import Counter

Counter(words).most_common(5)
# Out:
# [('DUMMY', 1), ('PLACEHOLDER', 1)]

# %%
# Implement

# %%
word_cnt = Counter(words)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Assuming you have a list of words called `words` containing the words from the book

# Create a word count object
word_count = Counter(words)

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_count)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Giả sử bạn có một danh sách chứa các từ từ tài liệu
words = ["VÕ THANH HUY", "HỒ THANH TRÚC", "VÕ HỒ TỐ QUYÊN", "VÕ THANH HOÀNG", "HỒ DUY ĐẠT PHÚC", "HỒ THANH LAN", "HỒ DUY DĂN"]

# Tạo đối tượng Counter để đếm tần suất của từng từ
word_count = Counter(words)

# Tạo đối tượng WordCloud từ tần suất đếm
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_count)

# Tùy chỉnh hiển thị WordCloud
wordcloud.recolor(random_state=42)  # Lựa chọn màu sắc ngẫu nhiên
wordcloud.generate_from_frequencies(word_count)  # Tái tạo WordCloud với tần suất đếm
wordcloud.to_file("wordcloud.png")  # Lưu WordCloud thành tệp hình ảnh

# Hiển thị WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import random

# Danh sách từ
words = ["VÕ THANH HUY", "HỒ THANH TRÚC", "VÕ HỒ TỐ QUYÊN", "VÕ THANH HOÀNG", "HỒ DUY ĐẠT PHÚC", "HỒ THANH LAN", "HỒ DUY DĂN"]

# Tạo đối tượng Counter để đếm tần suất của các từ
word_count = Counter(words)

# Tạo đối tượng WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white")

# Tùy chỉnh độ lớn và màu sắc của các từ trong WordCloud
wordcloud.generate_from_frequencies(word_count)
wordcloud.recolor(color_func=lambda *args, **kwargs: random.choice(["#FF0000", "#00FF00", "#0000FF", "#FFFF00", "#00FFFF"]))
wordcloud.to_file("wordcloud.png")

# Hiển thị WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Danh sách các từ
words = [
    "Northern Cyprus", "Kosovo", "Somaliland", "Afghanistan", "Albania", "Antarctica", "Algeria", "American Samoa",
    "Andorra", "Angola", "Antigua and Barbuda", "Azerbaijan", "Argentina", "Australia", "Austria", "Bahamas", "Bahrain",
    "Bangladesh", "Armenia", "Barbados", "Belgium", "Bermuda", "Bhutan", "Bolivia, Plurinational State of",
    "Bosnia and Herzegovina", "Botswana", "Bouvet Island", "Brazil", "Belize", "British Indian Ocean Territory",
    "Solomon Islands", "Virgin Islands, British", "Brunei Darussalam", "Bulgaria", "Myanmar", "Burundi", "Belarus",
    "Cambodia", "Cameroon", "Canada", "Cape Verde", "Cayman Islands", "Central African Republic", "Sri Lanka", "Chad",
    "Chile", "China", "Taiwan, Province of China", "Christmas Island", "Cocos (Keeling) Islands", "Colombia",
    "Comoros", "Mayotte", "Congo", "Congo, the Democratic Republic of the", "Cook Islands", "Costa Rica", "Croatia",
    "Cuba", "Cyprus", "Czech Republic", "Benin", "Denmark", "Dominica", "Dominican Republic", "Ecuador", "El Salvador",
    "Equatorial Guinea", "Ethiopia", "Eritrea", "Estonia", "Faroe Islands", "Falkland Islands (Malvinas)",
    "South Georgia and the South Sandwich Islands", "Fiji", "Finland", "Åland Islands", "France", "French Guiana",
    "French Polynesia", "French Southern Territories", "Djibouti", "Gabon", "Georgia", "Gambia",
    "Palestinian Territory, Occupied", "Germany", "Ghana", "Gibraltar", "Kiribati", "Greece", "Greenland", "Grenada",
    "Guadeloupe", "Guam", "Guatemala", "Guinea", "Guyana", "Haiti", "Heard Island and McDonald Islands",
    "Holy See (Vatican City State)", "Honduras", "Hong Kong", "Hungary", "Iceland", "India", "Indonesia",
    "Iran, Islamic Republic of", "Iraq", "Ireland", "Israel", "Italy", "Côte d'Ivoire", "Jamaica", "Japan",
    "Kazakhstan", "Jordan", "Kenya", "Korea, Democratic People's Republic of", "Korea, Republic of", "Kuwait",
    "Kyrgyzstan", "Lao People's Democratic Republic", "Lebanon", "Lesotho", "Latvia", "Liberia", "Libya",
    "Liechtenstein", "Lithuania", "Luxembourg", "Macao", "Madagascar", "Malawi", "Malaysia", "Maldives", "Mali",
    "Malta", "Martinique", "Mauritania", "Mauritius", "Mexico", "Monaco", "Mongolia", "Moldova, Republic of",
    "Montenegro", "Montserrat", "Morocco", "Mozambique", "Oman", "Namibia", "Nauru", "Nepal", "Netherlands", "Curaçao",
    "Aruba", "Sint Maarten (Dutch part)", "Bonaire, Sint Eustatius and Saba", "New Caledonia", "Vanuatu", "New Zealand",
    "Nicaragua", "Niger", "Nigeria", "Niue", "Norfolk Island", "Norway", "Northern Mariana Islands",
    "United States Minor Outlying Islands", "Micronesia, Federated States of", "Marshall Islands", "Palau", "Pakistan",
    "Panama", "Papua New Guinea", "Paraguay", "Peru", "Philippines", "Pitcairn", "Poland", "Portugal", "Guinea-Bissau",
    "Timor-Leste", "Puerto Rico", "Qatar", "Réunion", "Romania", "Russian Federation", "Rwanda", "Saint Barthélemy",
    "Saint Helena, Ascension and Tristan da Cunha", "Saint Kitts and Nevis", "Anguilla", "Saint Lucia",
    "Saint Martin (French part)", "Saint Pierre and Miquelon", "Saint Vincent and the Grenadines", "San Marino",
    "Sao Tome and Principe", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Sierra Leone", "Singapore", "Slovakia",
    "Viet Nam", "Slovenia", "Somalia", "South Africa", "Zimbabwe", "Spain", "South Sudan", "Sudan",
    "Western Sahara", "Suriname", "Svalbard and Jan Mayen", "Swaziland", "Sweden", "Switzerland",
    "Syrian Arab Republic", "Tajikistan", "Thailand", "Togo", "Tokelau", "Tonga", "Trinidad and Tobago",
    "United Arab Emirates", "Tunisia", "Turkey", "Turkmenistan", "Turks and Caicos Islands", "Tuvalu", "Uganda",
    "Ukraine", "Macedonia, the former Yugoslav Republic of", "Egypt", "United Kingdom", "Guernsey", "Jersey",
    "Isle of Man", "Tanzania, United Republic of", "United States", "Virgin Islands, U.S.", "Burkina Faso", "Uruguay",
    "Uzbekistan", "Venezuela, Bolivarian Republic of", "Wallis and Futuna", "Samoa", "Yemen", "Zambia"
]

# Tạo đối tượng Counter để đếm tần suất xuất hiện của các từ
word_count = Counter(words)

# Tạo đối tượng WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white")

# Tạo WordCloud từ tần suất đếm
wordcloud.generate_from_frequencies(word_count)

# Hiển thị WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# !pip install wordcloud
from wordcloud import WordCloud
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Danh sách các từ
words = [
    "VO THANH HUY", "ENVIRONMENTAL ENGINEERING", "https://orcid.org/0000-0002-0868-2064", "https://sciprofiles.com/profile/2541487", "WASTEWATER TREATMENT", "APPLICATION OF MACHINE LEARNING", "DATA ANALYTICS", "HUYPOCRISY@GMAIL.COM", "https://www.linkedin.com/in/huythanhvo", "Reality-oriented and application-driven advanced research", "Biological Wastewater Treatment", "Water Purification", "Electronic Waste", " Highly Conductive Concrete", "Biological Oxidation of H2S", "PYTHON", "R",
]

# Đường dẫn online đến hình ảnh của bạn
img_url = "https://f39-org-zp.zdn.vn/0e8b3cb2c7a12aff73b0.jpg"

# Tải hình ảnh từ URL
response = requests.get(img_url)
img = Image.open(BytesIO(response.content))

# Chuyển đổi hình ảnh thành mảng numpy
mask = np.array(img)

# Tạo WordCloud
wc = WordCloud(background_color="white", contour_width=3, contour_color='black', mask=mask)

# Tạo WordCloud từ danh sách từ
wc.generate(' '.join(words))

# Hiển thị WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ...
#      -------------------------------------- 152.1/152.1 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Danh sách các từ
words = [
    "VO THANH HUY", "ENVIRONMENTAL ENGINEERING", "https://orcid.org/0000-0002-0868-2064", "https://sciprofiles.com/profile/2541487", "WASTEWATER TREATMENT", "APPLICATION OF MACHINE LEARNING", "DATA ANALYTICS", "HUYPOCRISY@GMAIL.COM", "https://www.linkedin.com/in/huythanhvo", "Reality-oriented and application-driven advanced research", "Biological Wastewater Treatment", "Water Purification", "Electronic Waste", " Highly Conductive Concrete", "Biological Oxidation of H2S", "PYTHON", "R",
]

# Đường dẫn online đến hình ảnh của bạn
img_url = "https://github.com/huypocrisy/Thuc_hanh_NLP/blob/main/0e8b3cb2c7a12aff73b0.jpg"

# Tải hình ảnh từ URL
response = requests.get(img_url)
img = Image.open(BytesIO(response.content))

# Chuyển đổi hình ảnh thành mảng numpy
mask = np.array(img)

# Tạo màu từ ảnh
image_colors = ImageColorGenerator(mask)

# Tạo WordCloud
wc = WordCloud(background_color="white", max_words=1000, mask=mask, contour_width=3, contour_color='black')

# Tạo WordCloud từ danh sách từ
wc.generate(' '.join(words))

# Tạo hình ảnh kết hợp giữa WordCloud và ảnh gốc
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[4], line 18
#      16 # Tải hình ảnh từ URL
#      17 response = requests.get(img_url)
# ---> 18 img = Image.open(BytesIO(response.content))
#      20 # Chuyển đổi hình ảnh thành mảng numpy
#      21 mask = np.array(img)
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:3283, in open(fp, mode, formats)
#    3281     warnings.warn(message)
#    3282 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000024E4C52C3B0>

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Danh sách các từ
words = [
    "VO THANH HUY", "ENVIRONMENTAL ENGINEERING", "https://orcid.org/0000-0002-0868-2064", "https://sciprofiles.com/profile/2541487", "WASTEWATER TREATMENT", "APPLICATION OF MACHINE LEARNING", "DATA ANALYTICS", "HUYPOCRISY@GMAIL.COM", "https://www.linkedin.com/in/huythanhvo", "Reality-oriented and application-driven advanced research", "Biological Wastewater Treatment", "Water Purification", "Electronic Waste", " Highly Conductive Concrete", "Biological Oxidation of H2S", "PYTHON", "R",
]

# Đường dẫn online đến hình ảnh của bạn
img_url = "https://github.com/huypocrisy/Thuc_hanh_NLP/blob/main/0e8b3cb2c7a12aff73b0.jpg?raw=true" # Đã thay đổi liên kết trực tiếp đến hình ảnh

# Tải hình ảnh từ URL
response = requests.get(img_url)
img = Image.open(BytesIO(response.content))

# Chuyển đổi hình ảnh thành mảng numpy
mask = np.array(img)

# Tạo màu từ ảnh
image_colors = ImageColorGenerator(mask)

# Tạo WordCloud
wc = WordCloud(background_color="white", max_words=1000, mask=mask, contour_width=3, contour_color='black')

# Tạo WordCloud từ danh sách từ
wc.generate(' '.join(words))

# Tạo hình ảnh kết hợp giữa WordCloud và ảnh gốc
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt

# Danh sách các từ
words = [
    "VO THANH HUY", "ENVIRONMENTAL ENGINEERING", "https://orcid.org/0000-0002-0868-2064", "https://sciprofiles.com/profile/2541487", "WASTEWATER TREATMENT", "APPLICATION OF MACHINE LEARNING", "DATA ANALYTICS", "HUYPOCRISY@GMAIL.COM", "https://www.linkedin.com/in/huythanhvo", "Reality-oriented and application-driven advanced research", "Biological Wastewater Treatment", "Water Purification", "Electronic Waste", " Highly Conductive Concrete", "Biological Oxidation of H2S", "PYTHON", "R",
]

# Đường dẫn cục bộ đến hình ảnh của bạn
img_path = "E:/Ghub/huy.jpg"

# Đọc hình ảnh
img = Image.open(img_path)

# Chuyển hình ảnh sang đen trắng
img_bw = img.convert('1')

# Chuyển đổi hình ảnh thành mảng numpy
mask = np.array(img_bw)

# Tạo WordCloud
wc = WordCloud(width=800, height=400, background_color="white", max_words=1000, mask=mask, contour_width=3, contour_color='black')

# Tạo WordCloud từ danh sách từ
wc.generate(' '.join(words))

# Hiển thị WordCloud
plt.figure(figsize=[7,14])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Đường dẫn cục bộ đến hình ảnh của bạn
img_path = "E:/Ghub/huy.jpg"

# Đọc hình ảnh
img = Image.open(img_path)
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=856x855 at 0x24E4FB1EB00>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Đường dẫn cục bộ đến hình ảnh của bạn
img_path = "E:/Ghub/huy.jpg"

# Đọc hình ảnh
img = Image.open(img_path)

# Hiển thị hình ảnh
plt.imshow(img)
plt.show()

# %%
from PIL import Image

# Đường dẫn đến hình ảnh của bạn
img_path1 = "E:/Ghub/huy.jpg"
img_path2 = "E:/Ghub/huy1.png"

# Đọc hình ảnh
img1 = Image.open(img_path1)
img2 = Image.open(img_path2)

# Resize ảnh img1 để vừa với ảnh img2
img1 = img1.resize((int(img2.size[0]/3), int(img2.size[1]/3)))

# Tính toạ độ để đặt img1 vào trung tâm của img2
x = (img2.size[0] - img1.size[0]) // 2
y = (img2.size[1] - img1.size[1]) // 2

# Ghép ảnh
img2.paste(img1, (x, y))

# Hiển thị hình ảnh
img2.show()

# %%
from PIL import Image

# Đường dẫn đến hình ảnh của bạn
img_path1 = "E:/Ghub/huy.jpg"
img_path2 = "E:/Ghub/huy1.png"

# Đọc hình ảnh
img1 = Image.open(img_path1)
img2 = Image.open(img_path2)

# Resize ảnh img1 để vừa với ảnh img2
img1 = img1.resize((int(img2.size[0]/3), int(img2.size[1]/3)))

# Tính toạ độ để đặt img1 vào vị trí 1/3 từ trái sang của img2
x = img2.size[0] // 3 - img1.size[0] // 2
y = (img2.size[1] - img1.size[1]) // 2

# Ghép ảnh
img2.paste(img1, (x, y))

# Hiển thị hình ảnh
img2.show()
